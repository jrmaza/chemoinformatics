# %%
# !apt-get install -qq pkg-config libcairo2-dev 
# !pip3 install jupyter-manim --quiet
# !sudo apt-get -qq update
# !sudo apt-get install -qq texlive-full
# Out:
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# (Reading database ... 155685 files and directories currently installed.)
# Preparing to unpack .../libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
#      |████████████████████████████████| 4.8 MB 4.3 MB/s
#      |████████████████████████████████| 1.6 MB 43.4 MB/s
#      |████████████████████████████████| 340 kB 54.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Building wheel for jupyter-manim (setup.py) ... done
#   Building wheel for manimlib (setup.py) ... done
#   Building wheel for progressbar (setup.py) ... done
#   Building wheel for pycairo (PEP 517) ... done
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 371.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package install-info.
# (Reading database ... 155745 files and directories currently installed.)
# Preparing to unpack .../install-info_6.5.0.dfsg.1-2_amd64.deb ...
# Unpacking install-info (6.5.0.dfsg.1-2) ...
# Setting up install-info (6.5.0.dfsg.1-2) ...
# Selecting previously unselected package fonts-arphic-bkai00mp.
# (Reading database ... 155758 files and directories currently installed.)
# Preparing to unpack .../000-fonts-arphic-bkai00mp_2.10-17_all.deb ...
# Unpacking fonts-arphic-bkai00mp (2.10-17) ...
# Selecting previously unselected package fonts-arphic-bsmi00lp.
# Preparing to unpack .../001-fonts-arphic-bsmi00lp_2.10-17_all.deb ...
# Unpacking fonts-arphic-bsmi00lp (2.10-17) ...
# Selecting previously unselected package fonts-arphic-gbsn00lp.
# Preparing to unpack .../002-fonts-arphic-gbsn00lp_2.11-15_all.deb ...
# Unpacking fonts-arphic-gbsn00lp (2.11-15) ...
# Selecting previously unselected package fonts-arphic-gkai00mp.
# Preparing to unpack .../003-fonts-arphic-gkai00mp_2.11-15_all.deb ...
# Unpacking fonts-arphic-gkai00mp (2.11-15) ...
# Selecting previously unselected package fonts-baekmuk.
# Preparing to unpack .../004-fonts-baekmuk_2.2-12_all.deb ...
# Unpacking fonts-baekmuk (2.2-12) ...
# Selecting previously unselected package fonts-droid-fallback.
# Preparing to unpack .../005-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package fonts-ipaexfont-gothic.
# Preparing to unpack .../006-fonts-ipaexfont-gothic_00301-4ubuntu1_all.deb ...
# Unpacking fonts-ipaexfont-gothic (00301-4ubuntu1) ...
# Selecting previously unselected package fonts-ipaexfont-mincho.
# Preparing to unpack .../007-fonts-ipaexfont-mincho_00301-4ubuntu1_all.deb ...
# Unpacking fonts-ipaexfont-mincho (00301-4ubuntu1) ...
# Selecting previously unselected package fonts-ipafont-gothic.
# Preparing to unpack .../008-fonts-ipafont-gothic_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-18ubuntu1) ...
# Selecting previously unselected package fonts-ipafont-mincho.
# Preparing to unpack .../009-fonts-ipafont-mincho_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-mincho (00303-18ubuntu1) ...
# Selecting previously unselected package fonts-lato.
# Preparing to unpack .../010-fonts-lato_2.0-2_all.deb ...
# Unpacking fonts-lato (2.0-2) ...
# Selecting previously unselected package fonts-unfonts-core.
# Preparing to unpack .../011-fonts-unfonts-core_1%3a1.0.2-080608-14_all.deb ...
# Unpacking fonts-unfonts-core (1:1.0.2-080608-14) ...
# Selecting previously unselected package fonts-unfonts-extra.
# Preparing to unpack .../012-fonts-unfonts-extra_1%3a1.0.2-080608+dfsg-8_all.deb ...
# Unpacking fonts-unfonts-extra (1:1.0.2-080608+dfsg-8) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../013-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../014-imagemagick-6-common_8%3a6.9.7.4+dfsg-16ubuntu6.13_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package libmagickcore-6.q16-3:amd64.
# Preparing to unpack .../015-libmagickcore-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.13_amd64.deb ...
# Unpacking libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package libmagickwand-6.q16-3:amd64.
# Preparing to unpack .../016-libmagickwand-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.13_amd64.deb ...
# Unpacking libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../017-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../018-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package sgml-base.
# Preparing to unpack .../019-sgml-base_1.29_all.deb ...
# Unpacking sgml-base (1.29) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../020-tex-common_6.09_all.deb ...
# Unpacking tex-common (6.09) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../021-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../022-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package netbase.
# Preparing to unpack .../023-netbase_5.4_all.deb ...
# Unpacking netbase (5.4) ...
# Selecting previously unselected package info.
# Preparing to unpack .../024-info_6.5.0.dfsg.1-2_amd64.deb ...
# Unpacking info (6.5.0.dfsg.1-2) ...
# Selecting previously unselected package libgslcblas0:amd64.
# Preparing to unpack .../025-libgslcblas0_2.4+dfsg-6_amd64.deb ...
# Unpacking libgslcblas0:amd64 (2.4+dfsg-6) ...
# Selecting previously unselected package libgsl23:amd64.
# Preparing to unpack .../026-libgsl23_2.4+dfsg-6_amd64.deb ...
# Unpacking libgsl23:amd64 (2.4+dfsg-6) ...
# Selecting previously unselected package libosmesa6:amd64.
# Preparing to unpack .../027-libosmesa6_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libosmesa6:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../028-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../029-libcupsimage2_2.2.7-1ubuntu2.9_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.9) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../030-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../031-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../032-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.16_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../033-libgs9_9.26~dfsg+0-0ubuntu0.18.04.16_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../034-ghostscript_9.26~dfsg+0-0ubuntu0.18.04.16_amd64.deb ...
# Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Selecting previously unselected package imagemagick-6.q16.
# Preparing to unpack .../035-imagemagick-6.q16_8%3a6.9.7.4+dfsg-16ubuntu6.13_amd64.deb ...
# Unpacking imagemagick-6.q16 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package imagemagick.
# Preparing to unpack .../036-imagemagick_8%3a6.9.7.4+dfsg-16ubuntu6.13_amd64.deb ...
# Unpacking imagemagick (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package python3-pil.imagetk:amd64.
# Preparing to unpack .../037-python3-pil.imagetk_5.1.0-1ubuntu0.7_amd64.deb ...
# Unpacking python3-pil.imagetk:amd64 (5.1.0-1ubuntu0.7) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../038-python3-pil_5.1.0-1ubuntu0.7_amd64.deb ...
# Unpacking python3-pil:amd64 (5.1.0-1ubuntu0.7) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../039-libkpathsea6_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../040-libptexenc1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libsynctex1:amd64.
# Preparing to unpack .../041-libsynctex1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexlua52:amd64.
# Preparing to unpack .../042-libtexlua52_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../043-libtexluajit2_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../044-t1utils_1.41-2_amd64.deb ...
# Unpacking t1utils (1.41-2) ...
# Preparing to unpack .../045-libpoppler-private-dev_0.62.0-2ubuntu2.13_amd64.deb ...
# Unpacking libpoppler-private-dev:amd64 (0.62.0-2ubuntu2.13) over (0.62.0-2ubuntu2.12) ...
# Preparing to unpack .../046-libpoppler-dev_0.62.0-2ubuntu2.13_amd64.deb ...
# Unpacking libpoppler-dev:amd64 (0.62.0-2ubuntu2.13) over (0.62.0-2ubuntu2.12) ...
# Preparing to unpack .../047-libpoppler73_0.62.0-2ubuntu2.13_amd64.deb ...
# Unpacking libpoppler73:amd64 (0.62.0-2ubuntu2.13) over (0.62.0-2ubuntu2.12) ...
# Selecting previously unselected package libpotrace0.
# Preparing to unpack .../048-libpotrace0_1.14-2_amd64.deb ...
# Unpacking libpotrace0 (1.14-2) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../049-libzzip-0-13_0.13.62-3.1ubuntu0.18.04.1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../050-texlive-binaries_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../051-fonts-lmodern_2.004.5-3_all.deb ...
# Unpacking fonts-lmodern (2.004.5-3) ...
# Selecting previously unselected package texlive-base.
# Preparing to unpack .../052-texlive-base_2017.20180305-1_all.deb ...
# Unpacking texlive-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-base.
# Preparing to unpack .../053-texlive-latex-base_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-recommended.
# Preparing to unpack .../054-texlive-latex-recommended_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-recommended (2017.20180305-1) ...
# Selecting previously unselected package texlive-pictures.
# Preparing to unpack .../055-texlive-pictures_2017.20180305-1_all.deb ...
# Unpacking texlive-pictures (2017.20180305-1) ...
# Selecting previously unselected package texlive-plain-generic.
# Preparing to unpack .../056-texlive-plain-generic_2017.20180305-2_all.deb ...
# Unpacking texlive-plain-generic (2017.20180305-2) ...
# Selecting previously unselected package texlive-pstricks.
# Preparing to unpack .../057-texlive-pstricks_2017.20180305-2_all.deb ...
# Unpacking texlive-pstricks (2017.20180305-2) ...
# Selecting previously unselected package asymptote.
# Preparing to unpack .../058-asymptote_2.41-4_amd64.deb ...
# Unpacking asymptote (2.41-4) ...
# Selecting previously unselected package asymptote-doc.
# Preparing to unpack .../059-asymptote-doc_2.41-4_all.deb ...
# Unpacking asymptote-doc (2.41-4) ...
# Selecting previously unselected package libautovivification-perl.
# Preparing to unpack .../060-libautovivification-perl_0.17-1build1_amd64.deb ...
# Unpacking libautovivification-perl (0.17-1build1) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../061-libsub-name-perl_0.21-1build1_amd64.deb ...
# Unpacking libsub-name-perl (0.21-1build1) ...
# Selecting previously unselected package libclass-accessor-perl.
# Preparing to unpack .../062-libclass-accessor-perl_0.51-1_all.deb ...
# Unpacking libclass-accessor-perl (0.51-1) ...
# Selecting previously unselected package libnumber-compare-perl.
# Preparing to unpack .../063-libnumber-compare-perl_0.03-1_all.deb ...
# Unpacking libnumber-compare-perl (0.03-1) ...
# Selecting previously unselected package libtext-glob-perl.
# Preparing to unpack .../064-libtext-glob-perl_0.10-1_all.deb ...
# Unpacking libtext-glob-perl (0.10-1) ...
# Selecting previously unselected package libfile-find-rule-perl.
# Preparing to unpack .../065-libfile-find-rule-perl_0.34-1_all.deb ...
# Unpacking libfile-find-rule-perl (0.34-1) ...
# Selecting previously unselected package libdata-compare-perl.
# Preparing to unpack .../066-libdata-compare-perl_1.25-1_all.deb ...
# Unpacking libdata-compare-perl (1.25-1) ...
# Selecting previously unselected package libdata-dump-perl.
# Preparing to unpack .../067-libdata-dump-perl_1.23-1_all.deb ...
# Unpacking libdata-dump-perl (1.23-1) ...
# Selecting previously unselected package libdata-uniqid-perl.
# Preparing to unpack .../068-libdata-uniqid-perl_0.12-1_all.deb ...
# Unpacking libdata-uniqid-perl (0.12-1) ...
# Selecting previously unselected package libdate-simple-perl.
# Preparing to unpack .../069-libdate-simple-perl_3.0300-1build4_amd64.deb ...
# Unpacking libdate-simple-perl (3.0300-1build4) ...
# Selecting previously unselected package libclass-inspector-perl.
# Preparing to unpack .../070-libclass-inspector-perl_1.32-1_all.deb ...
# Unpacking libclass-inspector-perl (1.32-1) ...
# Selecting previously unselected package libfile-sharedir-perl.
# Preparing to unpack .../071-libfile-sharedir-perl_1.104-1_all.deb ...
# Unpacking libfile-sharedir-perl (1.104-1) ...
# Selecting previously unselected package libb-hooks-op-check-perl.
# Preparing to unpack .../072-libb-hooks-op-check-perl_0.22-1_amd64.deb ...
# Unpacking libb-hooks-op-check-perl (0.22-1) ...
# Selecting previously unselected package libdynaloader-functions-perl.
# Preparing to unpack .../073-libdynaloader-functions-perl_0.003-1_all.deb ...
# Unpacking libdynaloader-functions-perl (0.003-1) ...
# Selecting previously unselected package libdevel-callchecker-perl.
# Preparing to unpack .../074-libdevel-callchecker-perl_0.007-2build1_amd64.deb ...
# Unpacking libdevel-callchecker-perl (0.007-2build1) ...
# Selecting previously unselected package libparams-classify-perl.
# Preparing to unpack .../075-libparams-classify-perl_0.015-1_amd64.deb ...
# Unpacking libparams-classify-perl (0.015-1) ...
# Selecting previously unselected package libmodule-runtime-perl.
# Preparing to unpack .../076-libmodule-runtime-perl_0.016-1_all.deb ...
# Unpacking libmodule-runtime-perl (0.016-1) ...
# Selecting previously unselected package libtry-tiny-perl.
# Preparing to unpack .../077-libtry-tiny-perl_0.30-1_all.deb ...
# Unpacking libtry-tiny-perl (0.30-1) ...
# Selecting previously unselected package libmodule-implementation-perl.
# Preparing to unpack .../078-libmodule-implementation-perl_0.09-1_all.deb ...
# Unpacking libmodule-implementation-perl (0.09-1) ...
# Selecting previously unselected package libsub-exporter-progressive-perl.
# Preparing to unpack .../079-libsub-exporter-progressive-perl_0.001013-1_all.deb ...
# Unpacking libsub-exporter-progressive-perl (0.001013-1) ...
# Selecting previously unselected package libvariable-magic-perl.
# Preparing to unpack .../080-libvariable-magic-perl_0.62-1_amd64.deb ...
# Unpacking libvariable-magic-perl (0.62-1) ...
# Selecting previously unselected package libb-hooks-endofscope-perl.
# Preparing to unpack .../081-libb-hooks-endofscope-perl_0.21-1_all.deb ...
# Unpacking libb-hooks-endofscope-perl (0.21-1) ...
# Selecting previously unselected package libpackage-stash-perl.
# Preparing to unpack .../082-libpackage-stash-perl_0.37-1_all.deb ...
# Unpacking libpackage-stash-perl (0.37-1) ...
# Selecting previously unselected package libsub-identify-perl.
# Preparing to unpack .../083-libsub-identify-perl_0.14-1_amd64.deb ...
# Unpacking libsub-identify-perl (0.14-1) ...
# Selecting previously unselected package libnamespace-clean-perl.
# Preparing to unpack .../084-libnamespace-clean-perl_0.27-1_all.deb ...
# Unpacking libnamespace-clean-perl (0.27-1) ...
# Selecting previously unselected package libnamespace-autoclean-perl.
# Preparing to unpack .../085-libnamespace-autoclean-perl_0.28-1_all.deb ...
# Unpacking libnamespace-autoclean-perl (0.28-1) ...
# Selecting previously unselected package libparams-util-perl.
# Preparing to unpack .../086-libparams-util-perl_1.07-3build3_amd64.deb ...
# Unpacking libparams-util-perl (1.07-3build3) ...
# Selecting previously unselected package libsub-install-perl.
# Preparing to unpack .../087-libsub-install-perl_0.928-1_all.deb ...
# Unpacking libsub-install-perl (0.928-1) ...
# Selecting previously unselected package libdata-optlist-perl.
# Preparing to unpack .../088-libdata-optlist-perl_0.110-1_all.deb ...
# Unpacking libdata-optlist-perl (0.110-1) ...
# Selecting previously unselected package libsub-exporter-perl.
# Preparing to unpack .../089-libsub-exporter-perl_0.987-1_all.deb ...
# Unpacking libsub-exporter-perl (0.987-1) ...
# Selecting previously unselected package libeval-closure-perl.
# Preparing to unpack .../090-libeval-closure-perl_0.14-1_all.deb ...
# Unpacking libeval-closure-perl (0.14-1) ...
# Selecting previously unselected package libclass-data-inheritable-perl.
# Preparing to unpack .../091-libclass-data-inheritable-perl_0.08-2_all.deb ...
# Unpacking libclass-data-inheritable-perl (0.08-2) ...
# Selecting previously unselected package libdevel-stacktrace-perl.
# Preparing to unpack .../092-libdevel-stacktrace-perl_2.0300-1_all.deb ...
# Unpacking libdevel-stacktrace-perl (2.0300-1) ...
# Selecting previously unselected package libexception-class-perl.
# Preparing to unpack .../093-libexception-class-perl_1.44-1_all.deb ...
# Unpacking libexception-class-perl (1.44-1) ...
# Selecting previously unselected package libscalar-list-utils-perl.
# Preparing to unpack .../094-libscalar-list-utils-perl_1%3a1.50-1_amd64.deb ...
# Unpacking libscalar-list-utils-perl (1:1.50-1) ...
# Selecting previously unselected package libparams-validationcompiler-perl.
# Preparing to unpack .../095-libparams-validationcompiler-perl_0.26-1_all.deb ...
# Unpacking libparams-validationcompiler-perl (0.26-1) ...
# Selecting previously unselected package libalgorithm-c3-perl.
# Preparing to unpack .../096-libalgorithm-c3-perl_0.10-1_all.deb ...
# Unpacking libalgorithm-c3-perl (0.10-1) ...
# Selecting previously unselected package libclass-c3-perl.
# Preparing to unpack .../097-libclass-c3-perl_0.33-1_all.deb ...
# Unpacking libclass-c3-perl (0.33-1) ...
# Selecting previously unselected package libmro-compat-perl.
# Preparing to unpack .../098-libmro-compat-perl_0.13-1_all.deb ...
# Unpacking libmro-compat-perl (0.13-1) ...
# Selecting previously unselected package libclass-method-modifiers-perl.
# Preparing to unpack .../099-libclass-method-modifiers-perl_2.12-1_all.deb ...
# Unpacking libclass-method-modifiers-perl (2.12-1) ...
# Selecting previously unselected package librole-tiny-perl.
# Preparing to unpack .../100-librole-tiny-perl_2.000006-1_all.deb ...
# Unpacking librole-tiny-perl (2.000006-1) ...
# Selecting previously unselected package libsub-quote-perl.
# Preparing to unpack .../101-libsub-quote-perl_2.005000-1_all.deb ...
# Unpacking libsub-quote-perl (2.005000-1) ...
# Selecting previously unselected package libspecio-perl.
# Preparing to unpack .../102-libspecio-perl_0.42-1_all.deb ...
# Unpacking libspecio-perl (0.42-1) ...
# Selecting previously unselected package libdatetime-locale-perl.
# Preparing to unpack .../103-libdatetime-locale-perl_1%3a1.17-1_all.deb ...
# Unpacking libdatetime-locale-perl (1:1.17-1) ...
# Selecting previously unselected package libclass-singleton-perl.
# Preparing to unpack .../104-libclass-singleton-perl_1.5-1_all.deb ...
# Unpacking libclass-singleton-perl (1.5-1) ...
# Selecting previously unselected package libdatetime-timezone-perl.
# Preparing to unpack .../105-libdatetime-timezone-perl_1%3a2.18-1+2018d_all.deb ...
# Unpacking libdatetime-timezone-perl (1:2.18-1+2018d) ...
# Selecting previously unselected package libdatetime-perl.
# Preparing to unpack .../106-libdatetime-perl_2%3a1.46-1_amd64.deb ...
# Unpacking libdatetime-perl (2:1.46-1) ...
# Selecting previously unselected package libclass-factory-util-perl.
# Preparing to unpack .../107-libclass-factory-util-perl_1.7-3_all.deb ...
# Unpacking libclass-factory-util-perl (1.7-3) ...
# Selecting previously unselected package libpackage-deprecationmanager-perl.
# Preparing to unpack .../108-libpackage-deprecationmanager-perl_0.17-1_all.deb ...
# Unpacking libpackage-deprecationmanager-perl (0.17-1) ...
# Selecting previously unselected package libdatetime-format-strptime-perl.
# Preparing to unpack .../109-libdatetime-format-strptime-perl_1.7500-1_all.deb ...
# Unpacking libdatetime-format-strptime-perl (1.7500-1) ...
# Selecting previously unselected package libparams-validate-perl.
# Preparing to unpack .../110-libparams-validate-perl_1.29-1_amd64.deb ...
# Unpacking libparams-validate-perl (1.29-1) ...
# Selecting previously unselected package libdatetime-format-builder-perl.
# Preparing to unpack .../111-libdatetime-format-builder-perl_0.8100-1_all.deb ...
# Unpacking libdatetime-format-builder-perl (0.8100-1) ...
# Selecting previously unselected package libdatetime-calendar-julian-perl.
# Preparing to unpack .../112-libdatetime-calendar-julian-perl_0.04-1_all.deb ...
# Unpacking libdatetime-calendar-julian-perl (0.04-1) ...
# Selecting previously unselected package libencode-eucjpms-perl.
# Preparing to unpack .../113-libencode-eucjpms-perl_0.07-3build5_amd64.deb ...
# Unpacking libencode-eucjpms-perl (0.07-3build5) ...
# Selecting previously unselected package libencode-hanextra-perl.
# Preparing to unpack .../114-libencode-hanextra-perl_0.23-5_amd64.deb ...
# Unpacking libencode-hanextra-perl (0.23-5) ...
# Selecting previously unselected package libencode-jis2k-perl.
# Preparing to unpack .../115-libencode-jis2k-perl_0.03-1build3_amd64.deb ...
# Unpacking libencode-jis2k-perl (0.03-1build3) ...
# Selecting previously unselected package libfile-slurper-perl.
# Preparing to unpack .../116-libfile-slurper-perl_0.011-1_all.deb ...
# Unpacking libfile-slurper-perl (0.011-1) ...
# Selecting previously unselected package libipc-run3-perl.
# Preparing to unpack .../117-libipc-run3-perl_0.048-1_all.deb ...
# Unpacking libipc-run3-perl (0.048-1) ...
# Selecting previously unselected package perl-openssl-defaults:amd64.
# Preparing to unpack .../118-perl-openssl-defaults_3build1_amd64.deb ...
# Unpacking perl-openssl-defaults:amd64 (3build1) ...
# Selecting previously unselected package libnet-ssleay-perl.
# Preparing to unpack .../119-libnet-ssleay-perl_1.84-1ubuntu0.2_amd64.deb ...
# Unpacking libnet-ssleay-perl (1.84-1ubuntu0.2) ...
# Selecting previously unselected package libio-socket-ssl-perl.
# Preparing to unpack .../120-libio-socket-ssl-perl_2.060-3~ubuntu18.04.1_all.deb ...
# Unpacking libio-socket-ssl-perl (2.060-3~ubuntu18.04.1) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../121-liburi-perl_1.73-1_all.deb ...
# Unpacking liburi-perl (1.73-1) ...
# Selecting previously unselected package libnet-http-perl.
# Preparing to unpack .../122-libnet-http-perl_6.17-1_all.deb ...
# Unpacking libnet-http-perl (6.17-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../123-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../124-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../125-libhttp-date-perl_6.02-1_all.deb ...
# Unpacking libhttp-date-perl (6.02-1) ...
# Selecting previously unselected package libfile-listing-perl.
# Preparing to unpack .../126-libfile-listing-perl_6.04-1_all.deb ...
# Unpacking libfile-listing-perl (6.04-1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../127-libhtml-tagset-perl_3.20-3_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-3) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../128-libhtml-parser-perl_3.72-3build1_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-3build1) ...
# Selecting previously unselected package libhtml-tree-perl.
# Preparing to unpack .../129-libhtml-tree-perl_5.07-1_all.deb ...
# Unpacking libhtml-tree-perl (5.07-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../130-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../131-liblwp-mediatypes-perl_6.02-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.02-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../132-libhttp-message-perl_6.14-1_all.deb ...
# Unpacking libhttp-message-perl (6.14-1) ...
# Selecting previously unselected package libhttp-cookies-perl.
# Preparing to unpack .../133-libhttp-cookies-perl_6.04-1_all.deb ...
# Unpacking libhttp-cookies-perl (6.04-1) ...
# Selecting previously unselected package libhttp-negotiate-perl.
# Preparing to unpack .../134-libhttp-negotiate-perl_6.00-2_all.deb ...
# Unpacking libhttp-negotiate-perl (6.00-2) ...
# Selecting previously unselected package libwww-robotrules-perl.
# Preparing to unpack .../135-libwww-robotrules-perl_6.01-1_all.deb ...
# Unpacking libwww-robotrules-perl (6.01-1) ...
# Selecting previously unselected package libwww-perl.
# Preparing to unpack .../136-libwww-perl_6.31-1ubuntu0.1_all.deb ...
# Unpacking libwww-perl (6.31-1ubuntu0.1) ...
# Selecting previously unselected package liblwp-protocol-https-perl.
# Preparing to unpack .../137-liblwp-protocol-https-perl_6.07-2_all.deb ...
# Unpacking liblwp-protocol-https-perl (6.07-2) ...
# Selecting previously unselected package liblingua-translit-perl.
# Preparing to unpack .../138-liblingua-translit-perl_0.28-1_all.deb ...
# Unpacking liblingua-translit-perl (0.28-1) ...
# Selecting previously unselected package liblist-someutils-perl.
# Preparing to unpack .../139-liblist-someutils-perl_0.56-1_all.deb ...
# Unpacking liblist-someutils-perl (0.56-1) ...
# Selecting previously unselected package liblist-utilsby-perl.
# Preparing to unpack .../140-liblist-utilsby-perl_0.10-1_all.deb ...
# Unpacking liblist-utilsby-perl (0.10-1) ...
# Selecting previously unselected package liblist-allutils-perl.
# Preparing to unpack .../141-liblist-allutils-perl_0.14-1_all.deb ...
# Unpacking liblist-allutils-perl (0.14-1) ...
# Selecting previously unselected package libexporter-tiny-perl.
# Preparing to unpack .../142-libexporter-tiny-perl_1.000000-2_all.deb ...
# Unpacking libexporter-tiny-perl (1.000000-2) ...
# Selecting previously unselected package liblist-moreutils-perl.
# Preparing to unpack .../143-liblist-moreutils-perl_0.416-1build3_amd64.deb ...
# Unpacking liblist-moreutils-perl (0.416-1build3) ...
# Selecting previously unselected package liblog-log4perl-perl.
# Preparing to unpack .../144-liblog-log4perl-perl_1.49-1_all.deb ...
# Unpacking liblog-log4perl-perl (1.49-1) ...
# Selecting previously unselected package libreadonly-perl.
# Preparing to unpack .../145-libreadonly-perl_2.050-1_all.deb ...
# Unpacking libreadonly-perl (2.050-1) ...
# Selecting previously unselected package libregexp-common-perl.
# Preparing to unpack .../146-libregexp-common-perl_2017060201-1_all.deb ...
# Unpacking libregexp-common-perl (2017060201-1) ...
# Selecting previously unselected package libsort-key-perl.
# Preparing to unpack .../147-libsort-key-perl_1.33-2_amd64.deb ...
# Unpacking libsort-key-perl (1.33-2) ...
# Selecting previously unselected package libbtparse1.
# Preparing to unpack .../148-libbtparse1_0.85-1_amd64.deb ...
# Unpacking libbtparse1 (0.85-1) ...
# Selecting previously unselected package libtext-bibtex-perl.
# Preparing to unpack .../149-libtext-bibtex-perl_0.85-1_amd64.deb ...
# Unpacking libtext-bibtex-perl (0.85-1) ...
# Selecting previously unselected package libtext-csv-perl.
# Preparing to unpack .../150-libtext-csv-perl_1.95-1_all.deb ...
# Unpacking libtext-csv-perl (1.95-1) ...
# Selecting previously unselected package libtext-csv-xs-perl.
# Preparing to unpack .../151-libtext-csv-xs-perl_1.34-1_amd64.deb ...
# Unpacking libtext-csv-xs-perl (1.34-1) ...
# Selecting previously unselected package libtext-roman-perl.
# Preparing to unpack .../152-libtext-roman-perl_3.5-2_all.deb ...
# Unpacking libtext-roman-perl (3.5-2) ...
# Selecting previously unselected package libunicode-collate-perl.
# Preparing to unpack .../153-libunicode-collate-perl_1.25-1_amd64.deb ...
# Unpacking libunicode-collate-perl (1.25-1) ...
# Selecting previously unselected package libsombok3:amd64.
# Preparing to unpack .../154-libsombok3_2.4.0-1_amd64.deb ...
# Unpacking libsombok3:amd64 (2.4.0-1) ...
# Selecting previously unselected package libmime-charset-perl.
# Preparing to unpack .../155-libmime-charset-perl_1.012.2-1_all.deb ...
# Unpacking libmime-charset-perl (1.012.2-1) ...
# Selecting previously unselected package libunicode-linebreak-perl.
# Preparing to unpack .../156-libunicode-linebreak-perl_0.0.20160702-1build2_amd64.deb ...
# Unpacking libunicode-linebreak-perl (0.0.20160702-1build2) ...
# Selecting previously unselected package libxml-namespacesupport-perl.
# Preparing to unpack .../157-libxml-namespacesupport-perl_1.12-1_all.deb ...
# Unpacking libxml-namespacesupport-perl (1.12-1) ...
# Selecting previously unselected package libxml-sax-base-perl.
# Preparing to unpack .../158-libxml-sax-base-perl_1.09-1_all.deb ...
# Unpacking libxml-sax-base-perl (1.09-1) ...
# Selecting previously unselected package libxml-sax-perl.
# Preparing to unpack .../159-libxml-sax-perl_0.99+dfsg-2ubuntu1_all.deb ...
# Unpacking libxml-sax-perl (0.99+dfsg-2ubuntu1) ...
# Selecting previously unselected package libxml-libxml-perl.
# Preparing to unpack .../160-libxml-libxml-perl_2.0128+dfsg-5_amd64.deb ...
# Unpacking libxml-libxml-perl (2.0128+dfsg-5) ...
# Selecting previously unselected package libxml-libxml-simple-perl.
# Preparing to unpack .../161-libxml-libxml-simple-perl_0.99-1_all.deb ...
# Unpacking libxml-libxml-simple-perl (0.99-1) ...
# Selecting previously unselected package libxml-libxslt-perl.
# Preparing to unpack .../162-libxml-libxslt-perl_1.95-1build2_amd64.deb ...
# Unpacking libxml-libxslt-perl (1.95-1build2) ...
# Selecting previously unselected package libxml-writer-perl.
# Preparing to unpack .../163-libxml-writer-perl_0.625-1_all.deb ...
# Unpacking libxml-writer-perl (0.625-1) ...
# Selecting previously unselected package libbusiness-isbn-data-perl.
# Preparing to unpack .../164-libbusiness-isbn-data-perl_20140910.003-1_all.deb ...
# Unpacking libbusiness-isbn-data-perl (20140910.003-1) ...
# Selecting previously unselected package libbusiness-isbn-perl.
# Preparing to unpack .../165-libbusiness-isbn-perl_3.004-1_all.deb ...
# Unpacking libbusiness-isbn-perl (3.004-1) ...
# Selecting previously unselected package libtie-cycle-perl.
# Preparing to unpack .../166-libtie-cycle-perl_1.225-1_all.deb ...
# Unpacking libtie-cycle-perl (1.225-1) ...
# Selecting previously unselected package libbusiness-ismn-perl.
# Preparing to unpack .../167-libbusiness-ismn-perl_1.131-1_all.deb ...
# Unpacking libbusiness-ismn-perl (1.131-1) ...
# Selecting previously unselected package libbusiness-issn-perl.
# Preparing to unpack .../168-libbusiness-issn-perl_1.002-1_all.deb ...
# Unpacking libbusiness-issn-perl (1.002-1) ...
# Selecting previously unselected package biber.
# Preparing to unpack .../169-biber_2.9-1_all.deb ...
# Unpacking biber (2.9-1) ...
# Selecting previously unselected package chktex.
# Preparing to unpack .../170-chktex_1.7.6-1ubuntu1_amd64.deb ...
# Unpacking chktex (1.7.6-1ubuntu1) ...
# Selecting previously unselected package cm-super-minimal.
# Preparing to unpack .../171-cm-super-minimal_0.3.4-11_all.deb ...
# Unpacking cm-super-minimal (0.3.4-11) ...
# Selecting previously unselected package pfb2t1c2pfb.
# Preparing to unpack .../172-pfb2t1c2pfb_0.3-11_amd64.deb ...
# Unpacking pfb2t1c2pfb (0.3-11) ...
# Selecting previously unselected package cm-super.
# Preparing to unpack .../173-cm-super_0.3.4-11_all.deb ...
# Unpacking cm-super (0.3.4-11) ...
# Selecting previously unselected package rubygems-integration.
# Preparing to unpack .../174-rubygems-integration_1.11_all.deb ...
# Unpacking rubygems-integration (1.11) ...
# Selecting previously unselected package rake.
# Preparing to unpack .../175-rake_12.3.1-1ubuntu0.1_all.deb ...
# Unpacking rake (12.3.1-1ubuntu0.1) ...
# Selecting previously unselected package ruby-did-you-mean.
# Preparing to unpack .../176-ruby-did-you-mean_1.2.0-2_all.deb ...
# Unpacking ruby-did-you-mean (1.2.0-2) ...
# Selecting previously unselected package ruby-minitest.
# Preparing to unpack .../177-ruby-minitest_5.10.3-1_all.deb ...
# Unpacking ruby-minitest (5.10.3-1) ...
# Selecting previously unselected package ruby-net-telnet.
# Preparing to unpack .../178-ruby-net-telnet_0.1.1-2_all.deb ...
# Unpacking ruby-net-telnet (0.1.1-2) ...
# Selecting previously unselected package ruby-power-assert.
# Preparing to unpack .../179-ruby-power-assert_0.3.0-1_all.deb ...
# Unpacking ruby-power-assert (0.3.0-1) ...
# Selecting previously unselected package ruby-test-unit.
# Preparing to unpack .../180-ruby-test-unit_3.2.5-1_all.deb ...
# Unpacking ruby-test-unit (3.2.5-1) ...
# Selecting previously unselected package libruby2.5:amd64.
# Preparing to unpack .../181-libruby2.5_2.5.1-1ubuntu1.12_amd64.deb ...
# Unpacking libruby2.5:amd64 (2.5.1-1ubuntu1.12) ...
# Selecting previously unselected package ruby2.5.
# Preparing to unpack .../182-ruby2.5_2.5.1-1ubuntu1.12_amd64.deb ...
# Unpacking ruby2.5 (2.5.1-1ubuntu1.12) ...
# Selecting previously unselected package ruby.
# Preparing to unpack .../183-ruby_1%3a2.5.1_amd64.deb ...
# Unpacking ruby (1:2.5.1) ...
# Selecting previously unselected package texlive-metapost.
# Preparing to unpack .../184-texlive-metapost_2017.20180305-1_all.deb ...
# Unpacking texlive-metapost (2017.20180305-1) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../185-lmodern_2.004.5-3_all.deb ...
# Unpacking lmodern (2.004.5-3) ...
# Selecting previously unselected package tex-gyre.
# Preparing to unpack .../186-tex-gyre_20160520-1_all.deb ...
# Unpacking tex-gyre (20160520-1) ...
# Selecting previously unselected package context.
# Preparing to unpack .../187-context_2017.05.15.20170613-2_all.deb ...
# Unpacking context (2017.05.15.20170613-2) ...
# Selecting previously unselected package context-modules.
# Preparing to unpack .../188-context-modules_20170613-2_all.deb ...
# Unpacking context-modules (20170613-2) ...
# Selecting previously unselected package dvidvi.
# Preparing to unpack .../189-dvidvi_1.0-8.2_amd64.deb ...
# Unpacking dvidvi (1.0-8.2) ...
# Selecting previously unselected package dvipng.
# Preparing to unpack .../190-dvipng_1.15-1_amd64.deb ...
# Unpacking dvipng (1.15-1) ...
# Selecting previously unselected package emacsen-common.
# Preparing to unpack .../191-emacsen-common_2.0.8_all.deb ...
# Unpacking emacsen-common (2.0.8) ...
# Selecting previously unselected package texlive-font-utils.
# Preparing to unpack .../192-texlive-font-utils_2017.20180305-2_all.deb ...
# Unpacking texlive-font-utils (2017.20180305-2) ...
# Selecting previously unselected package texlive-extra-utils.
# Preparing to unpack .../193-texlive-extra-utils_2017.20180305-2_all.deb ...
# Unpacking texlive-extra-utils (2017.20180305-2) ...
# Selecting previously unselected package feynmf.
# Preparing to unpack .../194-feynmf_1.08-10_all.deb ...
# Unpacking feynmf (1.08-10) ...
# Selecting previously unselected package fonts-adf-accanthis.
# Preparing to unpack .../195-fonts-adf-accanthis_0.20110505-1_all.deb ...
# Unpacking fonts-adf-accanthis (0.20110505-1) ...
# Selecting previously unselected package fonts-adf-berenis.
# Preparing to unpack .../196-fonts-adf-berenis_0.20110505-1_all.deb ...
# Unpacking fonts-adf-berenis (0.20110505-1) ...
# Selecting previously unselected package fonts-adf-gillius.
# Preparing to unpack .../197-fonts-adf-gillius_0.20110505-1_all.deb ...
# Unpacking fonts-adf-gillius (0.20110505-1) ...
# Selecting previously unselected package fonts-adf-universalis.
# Preparing to unpack .../198-fonts-adf-universalis_0.20110505-1_all.deb ...
# Unpacking fonts-adf-universalis (0.20110505-1) ...
# Selecting previously unselected package fonts-cabin.
# Preparing to unpack .../199-fonts-cabin_1.5-2_all.deb ...
# Unpacking fonts-cabin (1.5-2) ...
# Selecting previously unselected package fonts-comfortaa.
# Preparing to unpack .../200-fonts-comfortaa_3.001-2_all.deb ...
# Unpacking fonts-comfortaa (3.001-2) ...
# Selecting previously unselected package fonts-croscore.
# Preparing to unpack .../201-fonts-croscore_20171026-2_all.deb ...
# Unpacking fonts-croscore (20171026-2) ...
# Selecting previously unselected package fonts-crosextra-caladea.
# Preparing to unpack .../202-fonts-crosextra-caladea_20130214-2_all.deb ...
# Unpacking fonts-crosextra-caladea (20130214-2) ...
# Selecting previously unselected package fonts-crosextra-carlito.
# Preparing to unpack .../203-fonts-crosextra-carlito_20130920-1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../204-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../205-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package fonts-ebgaramond.
# Preparing to unpack .../206-fonts-ebgaramond_0.016-1_all.deb ...
# Unpacking fonts-ebgaramond (0.016-1) ...
# Selecting previously unselected package fonts-ebgaramond-extra.
# Preparing to unpack .../207-fonts-ebgaramond-extra_0.016-1_all.deb ...
# Unpacking fonts-ebgaramond-extra (0.016-1) ...
# Selecting previously unselected package fonts-font-awesome.
# Preparing to unpack .../208-fonts-font-awesome_4.7.0~dfsg-3_all.deb ...
# Unpacking fonts-font-awesome (4.7.0~dfsg-3) ...
# Selecting previously unselected package fonts-freefont-otf.
# Preparing to unpack .../209-fonts-freefont-otf_20120503-7_all.deb ...
# Unpacking fonts-freefont-otf (20120503-7) ...
# Selecting previously unselected package fonts-freefont-ttf.
# Preparing to unpack .../210-fonts-freefont-ttf_20120503-7_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-7) ...
# Selecting previously unselected package fonts-gfs-artemisia.
# Preparing to unpack .../211-fonts-gfs-artemisia_1.1-5_all.deb ...
# Unpacking fonts-gfs-artemisia (1.1-5) ...
# Selecting previously unselected package fonts-gfs-baskerville.
# Preparing to unpack .../212-fonts-gfs-baskerville_1.1-5_all.deb ...
# Unpacking fonts-gfs-baskerville (1.1-5) ...
# Selecting previously unselected package fonts-gfs-bodoni-classic.
# Preparing to unpack .../213-fonts-gfs-bodoni-classic_1.1-5_all.deb ...
# Unpacking fonts-gfs-bodoni-classic (1.1-5) ...
# Selecting previously unselected package fonts-gfs-complutum.
# Preparing to unpack .../214-fonts-gfs-complutum_1.1-6_all.deb ...
# Unpacking fonts-gfs-complutum (1.1-6) ...
# Selecting previously unselected package fonts-gfs-didot.
# Preparing to unpack .../215-fonts-gfs-didot_1.1-6_all.deb ...
# Unpacking fonts-gfs-didot (1.1-6) ...
# Selecting previously unselected package fonts-gfs-didot-classic.
# Preparing to unpack .../216-fonts-gfs-didot-classic_1.1-5_all.deb ...
# Unpacking fonts-gfs-didot-classic (1.1-5) ...
# Selecting previously unselected package fonts-gfs-gazis.
# Preparing to unpack .../217-fonts-gfs-gazis_1.1-5_all.deb ...
# Unpacking fonts-gfs-gazis (1.1-5) ...
# Selecting previously unselected package fonts-gfs-neohellenic.
# Preparing to unpack .../218-fonts-gfs-neohellenic_1.1-6_all.deb ...
# Unpacking fonts-gfs-neohellenic (1.1-6) ...
# Selecting previously unselected package fonts-gfs-olga.
# Preparing to unpack .../219-fonts-gfs-olga_1.1-5_all.deb ...
# Unpacking fonts-gfs-olga (1.1-5) ...
# Selecting previously unselected package fonts-gfs-porson.
# Preparing to unpack .../220-fonts-gfs-porson_1.1-6_all.deb ...
# Unpacking fonts-gfs-porson (1.1-6) ...
# Selecting previously unselected package fonts-gfs-solomos.
# Preparing to unpack .../221-fonts-gfs-solomos_1.1-5_all.deb ...
# Unpacking fonts-gfs-solomos (1.1-5) ...
# Selecting previously unselected package fonts-gfs-theokritos.
# Preparing to unpack .../222-fonts-gfs-theokritos_1.1-5_all.deb ...
# Unpacking fonts-gfs-theokritos (1.1-5) ...
# Selecting previously unselected package fonts-go.
# Preparing to unpack .../223-fonts-go_0~20161116-1_all.deb ...
# Unpacking fonts-go (0~20161116-1) ...
# Selecting previously unselected package fonts-hosny-amiri.
# Preparing to unpack .../224-fonts-hosny-amiri_0.109-2_all.deb ...
# Unpacking fonts-hosny-amiri (0.109-2) ...
# Selecting previously unselected package fonts-junicode.
# Preparing to unpack .../225-fonts-junicode_1.001-2_all.deb ...
# Unpacking fonts-junicode (1.001-2) ...
# Selecting previously unselected package fonts-linuxlibertine.
# Preparing to unpack .../226-fonts-linuxlibertine_5.3.0-4_all.deb ...
# Unpacking fonts-linuxlibertine (5.3.0-4) ...
# Selecting previously unselected package fonts-lobster.
# Preparing to unpack .../227-fonts-lobster_2.0-2_all.deb ...
# Unpacking fonts-lobster (2.0-2) ...
# Selecting previously unselected package fonts-lobstertwo.
# Preparing to unpack .../228-fonts-lobstertwo_2.0-2_all.deb ...
# Unpacking fonts-lobstertwo (2.0-2) ...
# Selecting previously unselected package fonts-noto-hinted.
# Preparing to unpack .../229-fonts-noto-hinted_20171026-2_all.deb ...
# Unpacking fonts-noto-hinted (20171026-2) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../230-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package fonts-oflb-asana-math.
# Preparing to unpack .../231-fonts-oflb-asana-math_000.907-6_all.deb ...
# Unpacking fonts-oflb-asana-math (000.907-6) ...
# Selecting previously unselected package fonts-open-sans.
# Preparing to unpack .../232-fonts-open-sans_1.11-1_all.deb ...
# Unpacking fonts-open-sans (1.11-1) ...
# Selecting previously unselected package fonts-roboto-hinted.
# Preparing to unpack .../233-fonts-roboto-hinted_2%3a0~20160106-2_all.deb ...
# Unpacking fonts-roboto-hinted (2:0~20160106-2) ...
# Selecting previously unselected package fonts-sil-gentium.
# Preparing to unpack .../234-fonts-sil-gentium_20081126%3a1.03-2_all.deb ...
# Unpacking fonts-sil-gentium (20081126:1.03-2) ...
# Selecting previously unselected package fonts-sil-gentium-basic.
# Preparing to unpack .../235-fonts-sil-gentium-basic_1.102-1_all.deb ...
# Unpacking fonts-sil-gentium-basic (1.102-1) ...
# Selecting previously unselected package fonts-sil-gentiumplus.
# Preparing to unpack .../236-fonts-sil-gentiumplus_5.000-2_all.deb ...
# Unpacking fonts-sil-gentiumplus (5.000-2) ...
# Selecting previously unselected package fonts-sil-gentiumplus-compact.
# Preparing to unpack .../237-fonts-sil-gentiumplus-compact_5.000-2_all.deb ...
# Unpacking fonts-sil-gentiumplus-compact (5.000-2) ...
# Selecting previously unselected package fonts-sil-padauk.
# Preparing to unpack .../238-fonts-sil-padauk_3.003-1_all.deb ...
# Unpacking fonts-sil-padauk (3.003-1) ...
# Selecting previously unselected package fonts-texgyre.
# Preparing to unpack .../239-fonts-texgyre_20160520-1_all.deb ...
# Unpacking fonts-texgyre (20160520-1) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../240-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../241-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package lacheck.
# Preparing to unpack .../242-lacheck_1.26-17_amd64.deb ...
# Unpacking lacheck (1.26-17) ...
# Selecting previously unselected package latex-cjk-common.
# Preparing to unpack .../243-latex-cjk-common_4.8.4+git20170127-2_amd64.deb ...
# Unpacking latex-cjk-common (4.8.4+git20170127-2) ...
# Selecting previously unselected package latex-cjk-chinese.
# Preparing to unpack .../244-latex-cjk-chinese_4.8.4+git20170127-2_amd64.deb ...
# Unpacking latex-cjk-chinese (4.8.4+git20170127-2) ...
# Selecting previously unselected package latex-cjk-japanese.
# Preparing to unpack .../245-latex-cjk-japanese_4.8.4+git20170127-2_amd64.deb ...
# Unpacking latex-cjk-japanese (4.8.4+git20170127-2) ...
# Selecting previously unselected package latex-cjk-korean.
# Preparing to unpack .../246-latex-cjk-korean_4.8.4+git20170127-2_all.deb ...
# Unpacking latex-cjk-korean (4.8.4+git20170127-2) ...
# Selecting previously unselected package texlive-lang-other.
# Preparing to unpack .../247-texlive-lang-other_2017.20180305-1_all.deb ...
# Unpacking texlive-lang-other (2017.20180305-1) ...
# Selecting previously unselected package latex-cjk-thai.
# Preparing to unpack .../248-latex-cjk-thai_4.8.4+git20170127-2_all.deb ...
# Unpacking latex-cjk-thai (4.8.4+git20170127-2) ...
# Selecting previously unselected package latex-cjk-chinese-arphic-bsmi00lp.
# Preparing to unpack .../249-latex-cjk-chinese-arphic-bsmi00lp_1.23_all.deb ...
# Unpacking latex-cjk-chinese-arphic-bsmi00lp (1.23) ...
# Selecting previously unselected package latex-cjk-chinese-arphic-bkai00mp.
# Preparing to unpack .../250-latex-cjk-chinese-arphic-bkai00mp_1.23_all.deb ...
# Unpacking latex-cjk-chinese-arphic-bkai00mp (1.23) ...
# Selecting previously unselected package latex-cjk-chinese-arphic-gbsn00lp.
# Preparing to unpack .../251-latex-cjk-chinese-arphic-gbsn00lp_1.23_all.deb ...
# Unpacking latex-cjk-chinese-arphic-gbsn00lp (1.23) ...
# Selecting previously unselected package latex-cjk-chinese-arphic-gkai00mp.
# Preparing to unpack .../252-latex-cjk-chinese-arphic-gkai00mp_1.23_all.deb ...
# Unpacking latex-cjk-chinese-arphic-gkai00mp (1.23) ...
# Selecting previously unselected package latex-cjk-japanese-wadalab.
# Preparing to unpack .../253-latex-cjk-japanese-wadalab_0.20050817-17_all.deb ...
# Unpacking latex-cjk-japanese-wadalab (0.20050817-17) ...
# Selecting previously unselected package latex-cjk-all.
# Preparing to unpack .../254-latex-cjk-all_4.8.4+git20170127-2_all.deb ...
# Unpacking latex-cjk-all (4.8.4+git20170127-2) ...
# Selecting previously unselected package latexdiff.
# Preparing to unpack .../255-latexdiff_1.2.1-1_all.deb ...
# Unpacking latexdiff (1.2.1-1) ...
# Selecting previously unselected package latexmk.
# Preparing to unpack .../256-latexmk_1%3a4.41-1_all.deb ...
# ...
# Setting up fonts-sil-gentium (20081126:1.03-2) ...
# Setting up libgslcblas0:amd64 (2.4+dfsg-6) ...
# Setting up libsub-name-perl (0.21-1build1) ...
# Setting up libtext-csv-perl (1.95-1) ...
# Setting up chktex (1.7.6-1ubuntu1) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Setting up fonts-sil-gentium-basic (1.102-1) ...
# Setting up libsub-quote-perl (2.005000-1) ...
# Setting up libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Setting up libwww-robotrules-perl (6.01-1) ...
# Setting up libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up fonts-baekmuk (2.2-12) ...
# Setting up fonts-gfs-olga (1.1-5) ...
# Setting up libauthen-sasl-perl (2.1600-1) ...
# Setting up fonts-arphic-bkai00mp (2.10-17) ...
# Setting up libfile-slurper-perl (0.011-1) ...
# Setting up libclass-accessor-perl (0.51-1) ...
# Setting up libalgorithm-c3-perl (0.10-1) ...
# Setting up libsombok3:amd64 (2.4.0-1) ...
# Setting up libsort-key-perl (1.33-2) ...
# Setting up libclass-inspector-perl (1.32-1) ...
# Setting up fonts-lmodern (2.004.5-3) ...
# Setting up libclass-c3-perl (0.33-1) ...
# Setting up libclass-singleton-perl (1.5-1) ...
# Setting up ruby-power-assert (0.3.0-1) ...
# Setting up notification-daemon (3.20.0-3) ...
# Setting up fonts-gfs-gazis (1.1-5) ...
# Setting up fonts-roboto-hinted (2:0~20160106-2) ...
# Setting up netbase (5.4) ...
# Setting up libxml-sax-perl (0.99+dfsg-2ubuntu1) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::SAX::PurePerl with priority 10...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
#
# Creating config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up fonts-gfs-bodoni-classic (1.1-5) ...
# Setting up liblist-moreutils-perl (0.416-1build3) ...
# Setting up libdata-optlist-perl (0.110-1) ...
# Setting up libfile-find-rule-perl (0.34-1) ...
# Setting up libpoppler-glib8:amd64 (0.62.0-2ubuntu2.13) ...
# Setting up libhttp-date-perl (6.02-1) ...
# Setting up libpoppler-dev:amd64 (0.62.0-2ubuntu2.13) ...
# Setting up libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Setting up libdata-compare-perl (1.25-1) ...
# Setting up libexception-class-perl (1.44-1) ...
# Setting up libpoppler-qt5-1:amd64 (0.62.0-2ubuntu2.13) ...
# Setting up libgsl23:amd64 (2.4+dfsg-6) ...
# Setting up libdjvulibre21:amd64 (3.5.27.1-8ubuntu0.4) ...
# Setting up libnet-ssleay-perl (1.84-1ubuntu0.2) ...
# Setting up lcdf-typetools (2.106~dfsg-1) ...
# Setting up libdevel-callchecker-perl (0.007-2build1) ...
# Setting up fonts-lobstertwo (2.0-2) ...
# Setting up libbusiness-ismn-perl (1.131-1) ...
# Setting up x11-utils (7.7+3build1) ...
# Setting up ghostscript (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Setting up libmro-compat-perl (0.13-1) ...
# Setting up texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# update-alternatives: using /usr/bin/xdvi-xaw to provide /usr/bin/xdvi.bin (xdvi.bin) in auto mode
# update-alternatives: using /usr/bin/bibtex.original to provide /usr/bin/bibtex (bibtex) in auto mode
# Setting up libdevel-caller-perl (2.06-1build5) ...
# Setting up libio-socket-ssl-perl (2.060-3~ubuntu18.04.1) ...
# Setting up libhtml-tree-perl (5.07-1) ...
# Setting up libsub-exporter-perl (0.987-1) ...
# Setting up libtext-bibtex-perl (0.85-1) ...
# Setting up libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Setting up libunicode-linebreak-perl (0.0.20160702-1build2) ...
# Setting up texlive-base (2017.20180305-1) ...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# mktexlsr: Updating /var/lib/texmf/ls-R...
# mktexlsr: Done.
# tl-paper: setting paper size for dvips to a4: /var/lib/texmf/dvips/config/config-paper.ps
# tl-paper: setting paper size for dvipdfmx to a4: /var/lib/texmf/dvipdfmx/dvipdfmx-paper.cfg
# tl-paper: setting paper size for xdvi to a4: /var/lib/texmf/xdvi/XDvi-paper
# tl-paper: setting paper size for pdftex to a4: /var/lib/texmf/tex/generic/config/pdftexconfig.tex
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up texlive-latex-recommended-doc (2017.20180305-1) ...
# Setting up texlive-fonts-recommended-doc (2017.20180305-1) ...
# Setting up libfile-listing-perl (6.04-1) ...
# Setting up texlive-metapost (2017.20180305-1) ...
# Setting up libhttp-message-perl (6.14-1) ...
# Setting up ps2eps (1.68+binaryfree-2) ...
# Setting up texlive-fonts-extra-links (2017.20180305-2) ...
# Setting up libxml-libxml-perl (2.0128+dfsg-5) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::LibXML::SAX::Parser with priority 50...
# update-perl-sax-parsers: Registering Perl SAX parser XML::LibXML::SAX with priority 50...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Replacing config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up libeval-closure-perl (0.14-1) ...
# Setting up texlive-lang-other (2017.20180305-1) ...
# Setting up libparams-validationcompiler-perl (0.26-1) ...
# Setting up texlive-fonts-recommended (2017.20180305-1) ...
# Setting up texlive-plain-generic (2017.20180305-2) ...
# Setting up libfile-sharedir-perl (1.104-1) ...
# Setting up texlive-generic-recommended (2017.20180305-1) ...
# Setting up libparams-classify-perl (0.015-1) ...
# Setting up texlive-latex-base (2017.20180305-1) ...
# Setting up lmodern (2.004.5-3) ...
# Setting up texlive-latex-base-doc (2017.20180305-1) ...
# Setting up texlive-lang-portuguese (2017.20180305-1) ...
# Setting up texlive-lang-french (2017.20180305-1) ...
# Setting up libhttp-negotiate-perl (6.00-2) ...
# Setting up libxml-libxml-simple-perl (0.99-1) ...
# Setting up libdevel-lexalias-perl (0.05-1build5) ...
# Setting up texlive-science-doc (2017.20180305-2) ...
# Setting up texlive-latex-recommended (2017.20180305-1) ...
# Setting up texlive-extra-utils (2017.20180305-2) ...
# Setting up texlive-fonts-extra-doc (2017.20180305-2) ...
# Setting up libpoppler-private-dev:amd64 (0.62.0-2ubuntu2.13) ...
# Setting up texlive-lang-cjk (2017.20180305-1) ...
# Setting up texlive-lang-greek (2017.20180305-1) ...
# Setting up texlive-humanities-doc (2017.20180305-2) ...
# Setting up libnet-smtp-ssl-perl (1.04-1) ...
# Setting up libhtml-format-perl (2.12-1) ...
# Setting up texlive-fonts-extra (2017.20180305-2) ...
# Setting up texlive-pictures-doc (2017.20180305-1) ...
# Setting up texlive-science (2017.20180305-2) ...
# Setting up libhttp-cookies-perl (6.04-1) ...
# Setting up libmodule-runtime-perl (0.016-1) ...
# Setting up texlive-pstricks-doc (2017.20180305-2) ...
# Setting up texlive-pictures (2017.20180305-1) ...
# Setting up texlive-humanities (2017.20180305-2) ...
# Setting up dvipng (1.15-1) ...
# Setting up texlive-publishers (2017.20180305-2) ...
# Setting up tipa (2:1.3-20) ...
# Regenerating '/var/lib/texmf/fmtutil.cnf-DEBIAN'... done.
# Regenerating '/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST'... done.
# update-fmtutil has updated the following file(s):
# 	/var/lib/texmf/fmtutil.cnf-DEBIAN
# 	/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST
# If you want to activate the changes in the above file(s),
# you should run fmtutil-sys or fmtutil.
# Setting up imagemagick-6.q16 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare (compare) in auto mode
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare-im6 (compare-im6) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate (animate) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate-im6 (animate-im6) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert (convert) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert-im6 (convert-im6) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite (composite) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite-im6 (composite-im6) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure (conjure) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure-im6 (conjure-im6) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import (import) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import-im6 (import-im6) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify (identify) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify-im6 (identify-im6) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream (stream) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream-im6 (stream-im6) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display (display) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display-im6 (display-im6) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage (montage) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage-im6 (montage-im6) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify (mogrify) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify-im6 (mogrify-im6) in auto mode
# Setting up texlive-lang-arabic (2017.20180305-1) ...
# Setting up libhttp-daemon-perl (6.01-1ubuntu0.1) ...
# Setting up texlive-font-utils (2017.20180305-2) ...
# Setting up texlive-lang-spanish (2017.20180305-1) ...
# Setting up texlive-lang-european (2017.20180305-1) ...
# Setting up texlive-latex-extra-doc (2017.20180305-2) ...
# Setting up texlive-lang-italian (2017.20180305-1) ...
# Setting up texlive-publishers-doc (2017.20180305-2) ...
# Setting up libmagick++-6.q16-7:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Setting up texlive-luatex (2017.20180305-1) ...
# Setting up cm-super-minimal (0.3.4-11) ...
# Setting up libpstoedit0c2a (3.70-5) ...
# Setting up texlive-metapost-doc (2017.20180305-1) ...
# Setting up texlive-music (2017.20180305-2) ...
# Setting up texlive-lang-english (2017.20180305-1) ...
# Setting up libmagickcore-6.q16-3-extra:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Setting up texlive-lang-german (2017.20180305-1) ...
# Setting up libxml-libxslt-perl (1.95-1build2) ...
# Setting up texlive-games (2017.20180305-2) ...
# Setting up fragmaster (1.7-5) ...
# Setting up imagemagick (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Setting up libhtml-form-perl (6.03-1) ...
# Setting up texlive-lang-czechslovak (2017.20180305-1) ...
# Setting up prerex (6.5.4-1) ...
# Setting up texlive-lang-polish (2017.20180305-1) ...
# Setting up latexmk (1:4.41-1) ...
# Setting up libspecio-perl (0.42-1) ...
# Setting up texinfo (6.5.0.dfsg.1-2) ...
# Running mktexlsr. This may take some time. ... done.
# Setting up feynmf (1.08-10) ...
# Regenerating '/var/lib/texmf/fmtutil.cnf-DEBIAN'... done.
# Regenerating '/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST'... done.
# update-fmtutil has updated the following file(s):
# 	/var/lib/texmf/fmtutil.cnf-DEBIAN
# 	/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST
# If you want to activate the changes in the above file(s),
# you should run fmtutil-sys or fmtutil.
# Setting up vprerex (1:6.5.1-1) ...
# Setting up texlive-bibtex-extra (2017.20180305-2) ...
# Setting up texlive-lang-cyrillic (2017.20180305-1) ...
# Setting up libdist-checkconflicts-perl (0.11-1) ...
# Setting up texlive-lang-chinese (2017.20180305-1) ...
# Setting up texlive-pstricks (2017.20180305-2) ...
# Setting up texlive-lang-korean (2017.20180305-1) ...
# Setting up libmailtools-perl (2.18-1) ...
# Setting up texlive-latex-extra (2017.20180305-2) ...
# Setting up libmodule-implementation-perl (0.09-1) ...
# Setting up latex-cjk-common (4.8.4+git20170127-2) ...
# Setting up libmime-lite-perl (3.030-2) ...
# Setting up latex-cjk-thai (4.8.4+git20170127-2) ...
# Setting up cm-super (0.3.4-11) ...
# Creating fonts. This may take some time... done.
# Setting up libparams-validate-perl (1.29-1) ...
# Setting up pstoedit (3.70-5) ...
# Setting up latex-cjk-japanese (4.8.4+git20170127-2) ...
# Setting up libb-hooks-endofscope-perl (0.21-1) ...
# Setting up latex-cjk-chinese (4.8.4+git20170127-2) ...
# Setting up purifyeps (1.1-2) ...
# Setting up texlive-xetex (2017.20180305-1) ...
# Setting up liblist-someutils-perl (0.56-1) ...
# Setting up libpackage-stash-perl (0.37-1) ...
# Setting up asymptote (2.41-4) ...
# Setting up latex-cjk-korean (4.8.4+git20170127-2) ...
# Setting up texlive-formats-extra (2017.20180305-2) ...
# Setting up libpackage-deprecationmanager-perl (0.17-1) ...
# Setting up liblist-allutils-perl (0.14-1) ...
# Setting up libnamespace-clean-perl (0.27-1) ...
# Setting up latex-cjk-all (4.8.4+git20170127-2) ...
# Setting up libnamespace-autoclean-perl (0.28-1) ...
# Setting up liblog-dispatch-perl (2.67-1) ...
# Setting up libdatetime-timezone-perl (1:2.18-1+2018d) ...
# Setting up libdatetime-locale-perl (1:1.17-1) ...
# Setting up libdatetime-perl (2:1.46-1) ...
# Setting up libdatetime-format-strptime-perl (1.7500-1) ...
# Setting up libdatetime-calendar-julian-perl (0.04-1) ...
# Setting up libdatetime-format-builder-perl (0.8100-1) ...
# Setting up ruby-test-unit (3.2.5-1) ...
# Setting up rake (12.3.1-1ubuntu0.1) ...
# Setting up liblwp-protocol-https-perl (6.07-2) ...
# Setting up zathura (0.3.8-1) ...
# Setting up libwww-perl (6.31-1ubuntu0.1) ...
# Setting up zathura-pdf-poppler (0.2.8-1) ...
# Setting up libruby2.5:amd64 (2.5.1-1ubuntu1.12) ...
# Setting up libbusiness-isbn-perl (3.004-1) ...
# Setting up libxml-parser-perl (2.44-2build3) ...
# Setting up libxml-sax-expat-perl (0.40-2) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::SAX::Expat with priority 50...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Replacing config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up ruby2.5 (2.5.1-1ubuntu1.12) ...
# Setting up biber (2.9-1) ...
# Setting up ruby (1:2.5.1) ...
# Setting up texlive-lang-japanese (2017.20180305-1) ...
# Setting up context (2017.05.15.20170613-2) ...
# Running mtxrun --generate. This may take some time... done.
# Pregenerating ConTeXt MarkIV format. This may take some time... done.
# Setting up context-modules (20170613-2) ...
# Setting up texlive-full (2017.20180305-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for install-info (6.5.0.dfsg.1-2) ...
# Processing triggers for tex-common (6.09) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.
# Processing triggers for sgml-base (1.29) ...

# %%
import jupyter_manim

# %%
# %%manim OpeningScene --base64
# class OpeningScene(Scene):
#     def construct(self):
#         first_line = TextMobject("Data Structures and Algorithms")
#         second_line = TextMobject("Time Complexity and Big O Notation")
#         self.play(Write(first_line))
#         self.wait(2)
#         self.play(Transform(first_line, second_line))
#         self.wait(3)
#         self.play(FadeOut(first_line))
# Out:
#     <video
#       width="854"
#       height="480"
#       autoplay="autoplay"
#       controls
#     >
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
# %%manim OpeningScene --base64
#
# class Shapes(Scene):
#     def construct(self):
#         circle = Circle()
#         self.play(ShowCreation(circle))
# Out:
#     <video
#       width="854"
#       height="480"
#       autoplay="autoplay"
#       controls
#     >
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
# %%manim OpeningScene --base64
# class Shapes(Scene):
#     def construct(self):
#         ######Code######
#         #Making shapes
#         circle = Circle()
#         square = Square()
#         triangle=Polygon(np.array([0,0,0]),np.array([1,1,0]),np.array([1,-1,0]))
#
#         #Showing shapes
#         self.play(ShowCreation(circle))
#         self.play(FadeOut(circle))
#         self.play(GrowFromCenter(square))
#         self.play(Transform(square,triangle))
# Out:
#     <video
#       width="854"
#       height="480"
#       autoplay="autoplay"
#       controls
#     >
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
# %%manim OpeningScene --base64
#
# from math import cos, sin, pi
# class Shapes(Scene):
#     def construct(self):
#         #######Code#######
#         #Making Shapes
#         circle = Circle(color=YELLOW)
#         square = Square(color=DARK_BLUE)
#         square.surround(circle)
#
#         rectangle = Rectangle(height=2, width=3, color=RED)
#         ring=Annulus(inner_radius=.2, outer_radius=1, color=BLUE)
#         ring2 = Annulus(inner_radius=0.6, outer_radius=1, color=BLUE)
#         ring3=Annulus(inner_radius=.2, outer_radius=1, color=BLUE)
#         ellipse=Ellipse(width=5, height=3, color=DARK_BLUE)
#
#         pointers = []
#         for i in range(8):
#             pointers.append(Line(ORIGIN, np.array([cos(pi/180*360/8*i),sin(pi/180*360/8*i), 0]),color=YELLOW))
#
#         #Showing animation
#         self.add(circle)
#         self.play(FadeIn(square))
#         self.play(Transform(square, rectangle))
#         self.play(FadeOut(circle), FadeIn(ring))
#         self.play(Transform(ring,ring2))
#         self.play(Transform(ring2, ring))
#         self.play(FadeOut(square), GrowFromCenter(ellipse), Transform(ring2, ring3))
#         self.add(*pointers)
#         self.wait(2)
# Out:
#     <video
#       width="854"
#       height="480"
#       autoplay="autoplay"
#       controls
#     >
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
# %%manim OpeningScene --base64
#
# class makeText(Scene):
#     def construct(self):
#         #######Code#######
#         #Making text
#         first_line = TextMobject("Manim is fun")
#         second_line = TextMobject("and useful")
#         final_line = TextMobject("Hope you like it too!", color=BLUE)
#         color_final_line = TextMobject("Hope you like it too!")
#
#         #Coloring
#         color_final_line.set_color_by_gradient(YELLOW,PURPLE)
#
#         #Position text
#         second_line.next_to(first_line, DOWN)
#
#         #Showing text
#         self.wait(1)
#         self.play(Write(first_line), Write(second_line))
#         self.wait(1)
#         self.play(FadeOut(second_line), ReplacementTransform(first_line, final_line))
#         self.wait(1)
#         self.play(Transform(final_line, color_final_line))
#         self.wait(2)
# Out:
#     <video
#       width="854"
#       height="480"
#       autoplay="autoplay"
#       controls
#     >
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
# %%manim OpeningScene --base64
#
# from manimlib.imports import *
#
# class Equations(Scene):
#     def construct(self):
#         #Making equations
#         first_eq = TextMobject("$$J(\\theta) = -\\frac{1}{m} [\\sum_{i=1}^{m} y^{(i)} \\log{h_{\\theta}(x^{(i)})} + (1-y^{(i)}) \\log{(1-h_{\\theta}(x^{(i)}))}] $$")
#         second_eq = ["$J(\\theta_{0}, \\theta_{1})$", "=", "$\\frac{1}{2m}$", "$\\sum\\limits_{i=1}^m$", "(", "$h_{\\theta}(x^{(i)})$", "-", "$y^{(i)}$", "$)^2$"]
#
#         second_mob = TextMobject(*second_eq)
#
#         for i,item in enumerate(second_mob):
#             if(i != 0):
#                 item.next_to(second_mob[i-1],RIGHT)
#
#         eq2 = VGroup(*second_mob)
#
#         des1 = TextMobject("With manim, you can write complex equations like this...")
#         des2 = TextMobject("Or this...")
#         des3 = TextMobject("And it looks nice!!")
#
#         #Coloring equations
#         second_mob.set_color_by_gradient("#33ccff","#ff00ff")
#
#         #Positioning equations
#         des1.shift(2*UP)
#         des2.shift(2*UP)
#
#         #Animating equations
#         self.play(Write(des1))
#         self.play(Write(first_eq))
#         self.play(ReplacementTransform(des1, des2), Transform(first_eq, eq2))
#         self.wait(1)
#
#         for i, item in enumerate(eq2):
#             if (i<2):
#                 eq2[i].set_color(color=PURPLE)
#             else:
#                 eq2[i].set_color(color="#00FFFF")
#
#         self.add(eq2)
#         self.wait(1)
#         self.play(FadeOutAndShiftDown(eq2), FadeOutAndShiftDown(first_eq), Transform(des2, des3))
#         self.wait(2)
# Out:
#     <video
#       width="854"
#       height="480"
#       autoplay="autoplay"
#       controls
#     >
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
# %%manim OpeningScene --base64
#
# class Graphing(GraphScene):
#     CONFIG = {
#         "x_min": -5,
#         "x_max": 5,
#         "y_min": -4,
#         "y_max": 4,
#         "graph_origin": ORIGIN,
#         "function_color": WHITE,
#         "axes_color": BLUE
#     }
#
#     def construct(self):
#         #Make graph
#         self.setup_axes(animate=True)
#         func_graph=self.get_graph(self.func_to_graph,self.function_color)
#         graph_lab = self.get_graph_label(func_graph, label = "x^{2}")
#
#         func_graph_2=self.get_graph(self.func_to_graph_2,self.function_color)
#         graph_lab_2 = self.get_graph_label(func_graph_2, label = "x^{3}")
#
# #        vert_line = self.get_vertical_line_to_graph(1,func_graph,color=YELLOW)
#
#         x = self.coords_to_point(1, self.func_to_graph(1))
#         y = self.coords_to_point(0, self.func_to_graph(1))
# #        horz_line = Line(x,y, color=YELLOW)
#
# #        point = Dot(self.coords_to_point(1,self.func_to_graph(1)))
#
#         #Display graph
#         self.play(ShowCreation(func_graph), Write(graph_lab))
#         self.wait(2)
# #        self.play(ShowCreation(vert_line))
# #        self.play(ShowCreation(horz_line))
# #        self.add(point)
# #        self.wait(1)
#         self.play(Transform(func_graph, func_graph_2), Transform(graph_lab, graph_lab_2))
#         self.wait(2)
#
#
#     def func_to_graph(self, x):
#         return (x**2)
#
#     def func_to_graph_2(self, x):
#         return(x**3)
# Out:
#     <video
#       width="854"
#       height="480"
#       autoplay="autoplay"
#       controls
#     >
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
# %%manim OpeningScene --base64
#
# class Shapes(Scene):
#     def construct(self):
#         circle = Circle()
#         self.play(ShowCreation(circle))
# Out:
#     <video
#       width="854"
#       height="480"
#       autoplay="autoplay"
#       controls
#     >
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>
